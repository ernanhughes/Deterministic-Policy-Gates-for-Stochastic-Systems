# %%
# !pip install transformers torch pyyaml numpy, requests
# !git clone https://github.com/yourname/Deterministic-Policy-Gates-for-Stochastic-Systems.git
# %cd Deterministic-Policy-Gates-for-Stochastic-Systems

# !python scripts/download_feverous.py
# !python -m verity_gate.run_eval
